# %% [markdown]
# # Mendeteksi Image Malaria didalam Sel darah Merah menggunakan Python dengan Library Skimage metode Thresholding.
#
# By Mohammad Attala Rajafar
#
# Credit to :
#
# 1. Skimage Thresholding Documentation. Links : https://scikit-image.org/docs/stable/auto_examples/applications plot_thresholding.html
#
# 2. DigitalScreeni Youtube Channel. Links : https://www.youtube.com/watch?v=CTOURPZftuU&t=367s

# %% [markdown]
# Mengimport Library

# %%
import matplotlib.pyplot as plt
from skimage.filters import threshold_otsu, roberts
from skimage.io import imread
from skimage.color import rgb2gray
from skimage.feature import canny

# %% [markdown]
# Read Data

# %%
# Memanggil Gambar dari Direktori Local
image = imread('redbloodcells.PNG')
original = rgb2gray(image)

# %% [markdown]
# Thresholding Binary

# %%
# Membuat Thresholding Otsu (Binary) Method
thresh = threshold_otsu(original)
binary = original > thresh

# %% [markdown]
# Thresholding Roberts

# %%
# Membuat Thresholding Roberts Method
newthresh = roberts(original)

# %% [markdown]
# Thresholding Canny

# %%
# Membuat Thresholding Canny Method
newcanny = canny(original, sigma=1, high_threshold=0.6, low_threshold=0.6 ,use_quantiles=False)

# %% [markdown]
# Plot Visualization

# %%
# Membuat Plot Image untuk Figur ditempatkannya Image
fig, axes = plt.subplots(ncols=5, figsize=(18, 6))
ax = axes.ravel()

# Membuat Baris dan Kolom
ax[0] = plt.subplot(2, 5, 1)
ax[1] = plt.subplot(2, 5, 2)
ax[2] = plt.subplot(2, 5, 3, sharex=ax[0], sharey=ax[0])
ax[3] = plt.subplot(2, 5, 4, sharex=ax[0], sharey=ax[0])
ax[4] = plt.subplot(2, 5, 5, sharex=ax[0], sharey=ax[0])

# Plot di Kolom Pertama (Original)
ax[0].imshow(original, cmap=plt.cm.gray)
ax[0].set_title('Original')
ax[0].axis('off')

# Plot Image di Kolom Kedua (Histogram)
ax[1].hist(original.ravel(), bins=256)
ax[1].set_title('Histogram')
ax[1].axvline(thresh, color='r')

# Plot Image di Kolom Ketiga (Otsu Thresholding)
ax[2].imshow(binary, cmap=plt.cm.gray)
ax[2].set_title('Thresholded Otsu (Binary)')
ax[2].axis('off')

# Plot Image di Kolom Keempat (Roberts Thresholding)
ax[3].imshow(newthresh, cmap=plt.cm.gray)
ax[3].set_title('Thresholded Roberts')
ax[3].axis('off')

# Plot Image di Kolom Kelima (Canny Thresholding)
ax[4].imshow(newcanny, cmap=plt.cm.gray)
ax[4].set_title('Thresholded Canny')
ax[4].axis('off')

# Menampilkan Plot
plt.show()
